# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
results_data = pd.read_csv('/home/aarontjk/code/JanuariusJang/sportsanalytics/raw_data/Past_results_1993_2021.csv', encoding='windows-1252')
results_data.head()
# Out:
#     Season              DateTime     HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0  1993-94  1993-08-14T00:00:00Z      Arsenal        Coventry     0     3   A
# 1  1993-94  1993-08-14T00:00:00Z  Aston Villa             QPR     4     1   H
# 2  1993-94  1993-08-14T00:00:00Z      Chelsea       Blackburn     1     2   A
# 3  1993-94  1993-08-14T00:00:00Z    Liverpool  Sheffield Weds     2     0   H
# 4  1993-94  1993-08-14T00:00:00Z     Man City           Leeds     1     1   D
#
#    HTHG  HTAG  HTR  ... HST  AST  HC  AC  HF  AF  HY  AY  HR  AR
# 0   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 2   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 3   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 4   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# [5 rows x 23 columns]

# %%
resultsOnly_data=results_data[["Season", "HomeTeam", "AwayTeam", "FTHG", "FTAG"]]

# %%
resultsOnly_data.tail()
# Out:
#         Season     HomeTeam        AwayTeam  FTHG  FTAG
# 11108  2021-22  Aston Villa       Tottenham     0     4
# 11109  2021-22    Brentford        West Ham     2     0
# 11110  2021-22    Leicester  Crystal Palace     2     1
# 11111  2021-22      Norwich         Burnley     2     0
# 11112  2021-22     Man City       Liverpool     2     2

# %%
def label_WDL (row):
    if row['FTHG']>row['FTAG']:
        return 'W'
    if row['FTHG']<row['FTAG']:
        return 'L'
    if row['FTHG']==row['FTAG']:
        return 'D'

# %%
resultsOnly_data['WDL']=resultsOnly_data.apply(lambda row: label_WDL(row), axis=1)
# Out:
# /tmp/ipykernel_8094/2434092730.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resultsOnly_data['WDL']=resultsOnly_data.apply(lambda row: label_WDL(row), axis=1)

# %%
resultsOnly_data.head()
# Out:
#     Season     HomeTeam        AwayTeam  FTHG  FTAG WDL
# 0  1993-94      Arsenal        Coventry     0     3   L
# 1  1993-94  Aston Villa             QPR     4     1   W
# 2  1993-94      Chelsea       Blackburn     1     2   L
# 3  1993-94    Liverpool  Sheffield Weds     2     0   W
# 4  1993-94     Man City           Leeds     1     1   D

# %%
def winning_team (row):
    if row['WDL']=='W':
        return row['HomeTeam']
    if row['WDL']=='L':
        return row['AwayTeam']
    if row['WDL']=='D':
        return "NA"

# %%
resultsOnly_data['WinningTeam']=resultsOnly_data.apply(lambda row: winning_team(row), axis=1)
# Out:
# /tmp/ipykernel_8094/711549364.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resultsOnly_data['WinningTeam']=resultsOnly_data.apply(lambda row: winning_team(row), axis=1)

# %%
resultsOnly_data.drop('WinningTeam', axis=1, inplace=True)
# Out:
# /tmp/ipykernel_8094/2379643948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resultsOnly_data.drop('WinningTeam', axis=1, inplace=True)

# %%
resultsOnly_data.drop('Season', axis=1, inplace=True)
resultsOnly_data.drop('FTHG', axis=1, inplace=True)
resultsOnly_data.drop('FTAG', axis=1, inplace=True)
# Out:
# /tmp/ipykernel_8094/155072889.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resultsOnly_data.drop('Season', axis=1, inplace=True)
# /tmp/ipykernel_8094/155072889.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resultsOnly_data.drop('FTHG', axis=1, inplace=True)
# /tmp/ipykernel_8094/155072889.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resultsOnly_data.drop('FTAG', axis=1, inplace=True)

# %%
resultsOnly_data
# Out:
#           HomeTeam        AwayTeam WDL
# 0          Arsenal        Coventry   L
# 1      Aston Villa             QPR   W
# 2          Chelsea       Blackburn   L
# 3        Liverpool  Sheffield Weds   W
# 4         Man City           Leeds   D
# ...            ...             ...  ..
# 11108  Aston Villa       Tottenham   L
# 11109    Brentford        West Ham   W
# 11110    Leicester  Crystal Palace   W
# 11111      Norwich         Burnley   W
# 11112     Man City       Liverpool   D
#
# [11113 rows x 3 columns]

# %%
team_list
# Out:
# ['Arsenal',
#  'Aston Villa',
#  'Chelsea',
#  'Liverpool',
#  'Man City',
#  'Newcastle',
#  'Oldham',
#  'Sheffield United',
#  'Southampton',
#  'West Ham',
#  'Norwich',
#  'Tottenham',
#  'Everton',
#  'Ipswich',
#  'Leeds',
#  'Wimbledon',
#  'Blackburn',
#  'Coventry',
#  'Man United',
#  'QPR',
#  'Sheffield Weds',
#  'Swindon',
#  'Crystal Palace',
#  'Leicester',
#  "Nott'm Forest",
#  'Bolton',
#  'Middlesbrough',
#  'Derby',
#  'Sunderland',
#  'Barnsley',
#  'Charlton',
#  'Watford',
#  'Bradford',
#  'Fulham',
#  'Birmingham',
#  'West Brom',
#  'Portsmouth',
#  'Wolves',
#  'Wigan',
#  'Reading',
#  'Hull',
#  'Stoke',
#  'Burnley',
#  'Blackpool',
#  'Swansea',
#  'Cardiff',
#  'Bournemouth',
#  'Brighton',
#  'Huddersfield',
#  'Brentford']

# %%
team_list = list(resultsOnly_data['HomeTeam'].unique())

# %%
team_list2 = list(resultsOnly_data['AwayTeam'].unique())

# %%
len(team_list)
# Out:
# 50

# %%
arsenal_results = resultsOnly_data.query("HomeTeam == 'Arsenal' or AwayTeam == 'Arsenal'" )

# %%
arsenal_results.to_numpy()[2][2]
# Out:
# 'L'

# %%
arsenal_index = list(arsenal_results.index)

# %%
len(arsenal_index)
# Out:
# 1102

# %%
form = ['NA','NA','NA','NA','NA']
for i in range(5, len(arsenal_index)):
    form.append(arsenal_results.to_numpy()[i-5][2] + arsenal_results.to_numpy()[i-4][2] + arsenal_results.to_numpy()[i-3][2] + arsenal_results.to_numpy()[i-2][2] + arsenal_results.to_numpy()[i-1][2])

# %%
form
# Out:
# ['NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'LLLWW',
#  'LLWWD',
#  'LWWDW',
#  'WWDWW',
#  'WDWWW',
#  'DWWWD',
#  'WWWDD',
#  'WWDDD',
#  'WDDDD',
#  'DDDDL',
#  'DDDLL',
#  'DDLLD',
#  'DLLDW',
#  'LLDWW',
#  'LDWWD',
#  'DWWDW',
#  'WWDWW',
#  'WDWWL',
#  'DWWLW',
#  'WWLWL',
#  'WLWLD',
#  'LWLDD',
#  'WLDDD',
#  'LDDDD',
#  'DDDDD',
#  'DDDDW',
#  'DDDWL',
#  'DDWLL',
#  'DWLLD',
#  'WLLDW',
#  'LLDWD',
#  'LDWDD',
#  'DWDDW',
#  'WDDWD',
#  'DDWDL',
#  'DWDLD',
#  'WDLDL',
#  'DLDLW',
#  'LDLWW',
#  'DLWWW',
#  'LWWWW',
#  'WWWWD',
#  'WWWDD',
#  'WWDDL',
#  'WDDLL',
#  'DDLLL',
#  'DLLLL',
#  'LLLLW',
#  'LLLWW',
#  'LLWWD',
#  'LWWDD',
#  'WWDDW',
#  'WDDWW',
#  'DDWWD',
#  'DWWDD',
#  'WWDDL',
#  'WDDLL',
#  'DDLLD',
#  'DLLDL',
#  'LLDLL',
#  'LDLLW',
#  'DLLWD',
#  'LLWDL',
#  'LWDLD',
#  'WDLDW',
#  'DLDWD',
#  'LDWDW',
#  'DWDWL',
#  'WDWLL',
#  'DWLLW',
#  'WLLWW',
#  'LLWWW',
#  'LWWWW',
#  'WWWWW',
#  'WWWWL',
#  'WWWLW',
#  'WWLWL',
#  'WLWLD',
#  'LWLDD',
# ...

# %%
arsenal_results['Arsenal Form Numerical'] = form_numerical
# Out:
# /tmp/ipykernel_8094/1775793013.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   arsenal_results['Arsenal Form Numerical'] = form_numerical

# %%
form_numerical = []

form_dict = {'W':2, 'D':1, 'L':0}

for item in form:
    num = 0
    for letter in item:
        if letter == 'W':
            num += 2
        elif letter == 'D':
            num += 1
    form_numerical.append(num)

# %%
form_numerical
# Out:
# [0,
#  0,
#  0,
#  0,
#  0,
#  4,
#  5,
#  7,
#  9,
#  9,
#  8,
#  8,
#  7,
#  6,
#  4,
#  3,
#  3,
#  4,
#  5,
#  6,
#  8,
#  9,
#  7,
#  7,
#  6,
#  5,
#  4,
#  5,
#  4,
#  5,
#  6,
#  5,
#  4,
#  4,
#  5,
#  4,
#  5,
#  7,
#  7,
#  5,
#  5,
#  4,
#  4,
#  5,
#  7,
#  8,
#  9,
#  8,
#  6,
#  4,
#  2,
#  1,
#  2,
#  4,
#  5,
#  6,
#  8,
#  8,
#  7,
#  7,
#  6,
#  4,
#  3,
#  2,
#  1,
#  3,
#  4,
#  3,
#  4,
#  6,
#  5,
#  6,
#  6,
#  5,
#  5,
#  6,
#  6,
#  8,
#  10,
#  8,
#  8,
#  6,
#  5,
#  4,
#  6,
#  5,
#  5,
#  5,
#  5,
#  3,
#  4,
#  6,
#  7,
#  6,
#  8,
#  8,
#  8,
#  8,
#  10,
#  9,
#  8,
#  7,
#  6,
#  6,
#  7,
#  6,
#  7,
#  6,
#  4,
#  3,
#  3,
#  1,
#  2,
#  4,
#  3,
#  5,
#  7,
#  8,
#  8,
#  9,
#  8,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  6,
#  6,
#  4,
#  6,
#  5,
#  5,
#  5,
#  6,
#  6,
#  8,
#  7,
#  7,
#  7,
#  7,
#  6,
#  7,
#  7,
#  8,
#  8,
#  7,
#  7,
#  6,
#  4,
#  2,
#  2,
#  3,
#  2,
#  2,
#  2,
#  4,
#  3,
#  4,
#  4,
#  4,
#  3,
#  4,
#  3,
#  4,
#  5,
# ...

# %%
arsenal_results.head(10)
# Out:
#            HomeTeam     AwayTeam WDL  Arsenal Form Numerical
# 0           Arsenal     Coventry   L                       0
# 11        Tottenham      Arsenal   L                       0
# 29   Sheffield Weds      Arsenal   L                       0
# 34          Arsenal        Leeds   W                       0
# 45          Arsenal      Everton   W                       0
# 59        Blackburn      Arsenal   D                       4
# 66          Arsenal      Ipswich   W                       5
# 86       Man United      Arsenal   W                       7
# 88          Arsenal  Southampton   W                       9
# 101       Liverpool      Arsenal   D                       9

# %%
arsenal_results = arsenal_results.iloc[5:,:]

# %%
arsenal_results
# Out:
#              HomeTeam     AwayTeam WDL  Arsenal Form Numerical
# 59          Blackburn      Arsenal   D                       4
# 66            Arsenal      Ipswich   W                       5
# 86         Man United      Arsenal   W                       7
# 88            Arsenal  Southampton   W                       9
# 101         Liverpool      Arsenal   D                       9
# ...               ...          ...  ..                     ...
# 11083         Arsenal    Leicester   W                       5
# 11086         Arsenal    Liverpool   L                       6
# 11089     Aston Villa      Arsenal   L                       6
# 11101  Crystal Palace      Arsenal   W                       4
# 11105         Arsenal     Brighton   L                       4
#
# [1097 rows x 4 columns]

# %%
resultsOnly_data.query("AwayTeam == 'Coventry'")
# Out:
#        Season     HomeTeam  AwayTeam  FTHG  FTAG WDL  WinningTeam
# 0     1993-94      Arsenal  Coventry     0     3   L     Coventry
# 36    1993-94       Oldham  Coventry     3     3   D           NA
# 44    1993-94     Man City  Coventry     1     1   D           NA
# 67    1993-94  Aston Villa  Coventry     0     0   D           NA
# 102   1993-94      Norwich  Coventry     1     0   W      Norwich
# ...       ...          ...       ...   ...   ...  ..          ...
# 3116  2000-01    Tottenham  Coventry     3     0   W    Tottenham
# 3134  2000-01    Leicester  Coventry     1     3   L     Coventry
# 3148  2000-01   Man United  Coventry     4     2   W   Man United
# 3162  2000-01      Ipswich  Coventry     2     0   W      Ipswich
# 3181  2000-01  Aston Villa  Coventry     3     2   W  Aston Villa
#
# [156 rows x 7 columns]

# %%
for index in arsenal_index:
    arsenal_results

# %%
arsenal_results.WDL
# Out:
# 0        L
# 11       L
# 29       L
# 34       W
# 45       W
#         ..
# 11083    W
# 11086    L
# 11089    L
# 11101    W
# 11105    L
# Name: WDL, Length: 1102, dtype: object
