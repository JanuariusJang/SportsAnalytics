# %%
import pandas as pd

# %%
a = pd.read_csv("../raw_data/samson/fotmob-premier-league-players-matches.csv")

# %%
a
# Out:
#       player_id                match_date  match_id          match_home_team  \
# 0        675088  2023-03-14T21:00:00.000Z   4060601          Manchester City
# 1        675088  2023-03-11T18:30:00.000Z   3901193           Crystal Palace
# 2        675088  2023-03-04T13:30:00.000Z   3901188          Manchester City
# 3        675088  2023-02-28T21:00:00.000Z   4113167             Bristol City
# 4        675088  2023-02-25T18:30:00.000Z   3901172          AFC Bournemouth
# ...         ...                       ...       ...                      ...
# 4270      19243  2022-12-20T20:45:00.000Z   4062028  Wolverhampton Wanderers
# 4271      19243  2022-10-29T16:00:00.000Z   3901064                Brentford
# 4272      19243  2022-10-23T15:00:00.000Z   3901061  Wolverhampton Wanderers
# 4273      19243  2022-10-18T21:15:00.000Z   3901048           Crystal Palace
# 4274      19243  2022-10-15T16:00:00.000Z   3901041  Wolverhampton Wanderers
#
# ...

# %%
b = pd.read_csv("../raw_data/samson/fotmob-premier-league-players.csv")

# %%
b
# Out:
#      player_id           player_name  team_id team_color  \
# 0       675088                 Rodri     8456    #69A8D8
# 1       191869       Kieran Trippier    10261    #000000
# 2       961995           Bukayo Saka     9825    #bd0510
# 3       434325         Thomas Partey     9825    #bd0510
# 4       534670       Martin Ødegaard     9825    #bd0510
# ..         ...                   ...      ...        ...
# 280     819762          Chris Mepham     8678    #901818
# 281     158545       Michail Antonio     8654    #66192C
# 282     706297  Jean-Philippe Mateta     9826    #004A97
# 283    1177312            Sékou Mara     8466    #d71920
# 284      19243           Diego Costa     8602    #000000
#
#                         team       player_position_primary  \
# 0            Manchester City            Central Midfielder
# 1           Newcastle United                    Right Back
# 2                    Arsenal                  Right Winger
# ...

# %%
    b.query("team == 'AFC Bournemouth'")
# Out:
#      player_id       player_name  team_id team_color             team  \
# 60      789630  Marcus Tavernier     8678    #901818  AFC Bournemouth
# 92      532743    Philip Billing     8678    #901818  AFC Bournemouth
# 109     466672   Jefferson Lerma     8678    #901818  AFC Bournemouth
# 137     176186              Neto     8678    #901818  AFC Bournemouth
# 159     562724        Lewis Cook     8678    #901818  AFC Bournemouth
# 207     785411     Marcos Senesi     8678    #901818  AFC Bournemouth
# 212     982633     Jordan Zemura     8678    #901818  AFC Bournemouth
# 222     439369     Ryan Christie     8678    #901818  AFC Bournemouth
# 240     591734   Dominic Solanke     8678    #901818  AFC Bournemouth
# 242    1171140    Jaidon Anthony     8678    #901818  AFC Bournemouth
# 262     160447        Adam Smith     8678    #901818  AFC Bournemouth
# 272     469202     Kieffer Moore     8678    #901818  AFC Bournemouth
# ...

# %%
attributes = pd.read_csv("../raw_data/player_attributes.csv")

# %%
attributes
# Out:
#      player_id       player_name  team_id team_color                     team  \
# 0       789630  Marcus Tavernier     8678    #901818          AFC Bournemouth
# 1       532743    Philip Billing     8678    #901818          AFC Bournemouth
# 2       466672   Jefferson Lerma     8678    #901818          AFC Bournemouth
# 3       176186              Neto     8678    #901818          AFC Bournemouth
# 4       562724        Lewis Cook     8678    #901818          AFC Bournemouth
# ..         ...               ...      ...        ...                      ...
# 280     416175           José Sá     8602    #000000  Wolverhampton Wanderers
# 281     961306    Nathan Collins     8602    #000000  Wolverhampton Wanderers
# 282     493647      Adama Traoré     8602    #000000  Wolverhampton Wanderers
# 283     620026    Hee-Chan Hwang     8602    #000000  Wolverhampton Wanderers
# 284      19243       Diego Costa     8602    #000000  Wolverhampton Wanderers
#
#     player_position_primary  \
# ...
