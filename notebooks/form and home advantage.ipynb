# %%
import pandas as pd

# %%
df = pd.read_csv("/home/aarontjk/code/JanuariusJang/sportsanalytics/raw_data/Past_results_1993_2021.csv", encoding='windows-1252')

# %%
df.head(5)
# Out:
#     Season              DateTime     HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0  1993-94  1993-08-14T00:00:00Z      Arsenal        Coventry     0     3   A
# 1  1993-94  1993-08-14T00:00:00Z  Aston Villa             QPR     4     1   H
# 2  1993-94  1993-08-14T00:00:00Z      Chelsea       Blackburn     1     2   A
# 3  1993-94  1993-08-14T00:00:00Z    Liverpool  Sheffield Weds     2     0   H
# 4  1993-94  1993-08-14T00:00:00Z     Man City           Leeds     1     1   D
#
#    HTHG  HTAG  HTR  ... HST  AST  HC  AC  HF  AF  HY  AY  HR  AR
# 0   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 2   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 3   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 4   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# [5 rows x 23 columns]

# %%
df.query("HomeTeam == 'Man United' or AwayTeam =='Man United'")
# Out:
#         Season              DateTime     HomeTeam          AwayTeam  FTHG  \
# 10     1993-94  1993-08-15T00:00:00Z      Norwich        Man United     0
# 18     1993-94  1993-08-18T00:00:00Z   Man United  Sheffield United     3
# 27     1993-94  1993-08-21T00:00:00Z   Man United         Newcastle     1
# 33     1993-94  1993-08-23T00:00:00Z  Aston Villa        Man United     1
# 52     1993-94  1993-08-28T00:00:00Z  Southampton        Man United     1
# ...        ...                   ...          ...               ...   ...
# 11056  2021-22  2022-02-26T15:00:00Z   Man United           Watford     0
# 11069  2021-22  2022-03-06T16:30:00Z     Man City        Man United     4
# 11077  2021-22  2022-03-12T17:30:00Z   Man United         Tottenham     3
# 11098  2021-22  2022-04-02T17:30:00Z   Man United         Leicester     1
# 11104  2021-22  2022-04-09T12:30:00Z      Everton        Man United     1
#
#        FTAG FTR  HTHG  HTAG  HTR  ...   HST  AST   HC   AC    HF    AF   HY  \
# ...
