# %%
#imports

import pandas as pd

# %%
#read CSVs

# %%
attributes = pd.read_csv("../raw_data/FM 2023.csv")

# %%
player_info = pd.read_csv("../raw_data/player_info.csv")

# %%
lineups = pd.read_json("../raw_data/epl_2022_2023_07_02_2023.json")

# %%
attributes.head(5)
# Out:
#                  Name  Position  Age   ca   pa     Nationality  \
# 0     Kevin De Bruyne  M/AM RLC   31  189  189         Belgium
# 1       Kylian Mbappé   AM/S RL   23  188  197          France
# 2  Robert Lewandowski         S   33  186  190          Poland
# 3      Erling Haaland         S   22  185  195  Norway,England
# 4       Mohamed Salah   AM/S RL   30  185  187           Egypt
#
#                   Club  Corners  Crossing  Dribbling  ...  World reputation  \
# 0      Manchester City       14        19         15  ...              9400
# 1  Paris Saint-Germain       13        13         18  ...              9248
# 2            Barcelona        3         8         13  ...              9250
# 3      Manchester City        7        10         14  ...              8750
# 4            Liverpool       12        14         17  ...              8750
#
#                             Race  RCA  Colour of skin  Date of birth  \
# ...

# %%
player_info.head(5)
# Out:
#    Unnamed: 0       player_name             team    birthday position
# 0           0  Daniel Adu-Adjei  AFC Bournemouth  21/06/2005       FW
# 1           1    Jaidon Anthony  AFC Bournemouth  01/12/1999       FW
# 2           2    Philip Billing  AFC Bournemouth  11/06/1996       MF
# 3           3      David Brooks  AFC Bournemouth  08/07/1997       FW
# 4           4     Ryan Christie  AFC Bournemouth  22/02/1995       MF

# %%
lineups.head(5)
# Out:
#                                                    event     matchweek  \
# 75091  [Full-time Match ends, Arsenal 0, Newcastle Un...  Matchweek 19
# 75096  [Full-time Match ends, Everton 1, Brighton and...  Matchweek 19
# 75098  [Full-time Match ends, Leicester City 0, Fulha...  Matchweek 19
# 75099  [Full-time Match ends, Manchester United 3, Bo...  Matchweek 19
# 75093  [Full-time Match ends, Brentford 3, Liverpool ...  Matchweek 19
#
#               team1_name                                    team1_startings  \
# 75091            Arsenal  [Aaron Ramsdale, Ben White, Gabriel Magalhães,...
# 75096            Everton  [Jordan Pickford, James Tarkowski, Nathan Patt...
# 75098     Leicester City  [Danny Ward, Wout Faes, Daniel Amartey, Timoth...
# 75099  Manchester United  [David de Gea, Victor Lindelöf, Harry Maguire,...
# 75093          Brentford  [David Raya, Ethan Pinnock, Zanka, Ben Mee, Ri...
#
#                                               team1_subs  \
# ...

# %%
lineups = lineups.transpose()

# %%
lineups['match'] = lineups['team1_name'] + ' v ' + lineups['team2_name']

# %%
lineups.head(5)
# Out:
#                                                    event     matchweek  \
# 75091  [Full-time Match ends, Arsenal 0, Newcastle Un...  Matchweek 19
# 75096  [Full-time Match ends, Everton 1, Brighton and...  Matchweek 19
# 75098  [Full-time Match ends, Leicester City 0, Fulha...  Matchweek 19
# 75099  [Full-time Match ends, Manchester United 3, Bo...  Matchweek 19
# 75093  [Full-time Match ends, Brentford 3, Liverpool ...  Matchweek 19
#
#               team1_name                                    team1_startings  \
# 75091            Arsenal  [Aaron Ramsdale, Ben White, Gabriel Magalhães,...
# 75096            Everton  [Jordan Pickford, James Tarkowski, Nathan Patt...
# 75098     Leicester City  [Danny Ward, Wout Faes, Daniel Amartey, Timoth...
# 75099  Manchester United  [David de Gea, Victor Lindelöf, Harry Maguire,...
# 75093          Brentford  [David Raya, Ethan Pinnock, Zanka, Ben Mee, Ri...
#
#                                               team1_subs  \
# ...

# %%
test = lineups.query("team1_name == 'Manchester City'")

# %%
test['team1_startings'][75085]
# Out:
# ['Ederson',
#  'John Stones',
#  'Nathan Aké',
#  'Manuel Akanji',
#  'Rico Lewis',
#  'Rodri',
#  'Kevin De Bruyne',
#  'Bernardo Silva',
#  'Erling Haaland',
#  'Jack Grealish',
#  'Riyad Mahrez']
